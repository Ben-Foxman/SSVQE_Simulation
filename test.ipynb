# %%
import pandas as pd

# %%
pd.read_pickle("SSVQE_results.df")
# Out:
#                     Date/Time       Hamiltonian            Weight Name  \
# 0  2022-07-06 23:53:20.706796  1D Infinite Well  SSVQE_curved_2_qubits
# 1  2022-07-06 23:57:20.319733  1D Infinite Well  SSVQE_curved_2_qubits
# 2  2022-07-07 00:01:35.165561  1D Infinite Well  SSVQE_curved_2_qubits
# 3  2022-07-07 19:39:54.541661  1D Infinite Well  SSVQE_curved_2_qubits
# 4  2022-07-07 19:43:21.188757  1D Infinite Well  SSVQE_curved_2_qubits
# 5  2022-07-07 19:45:39.325150  1D Infinite Well  SSVQE_curved_2_qubits
# 6  2022-07-07 19:47:59.377778  1D Infinite Well  SSVQE_curved_2_qubits
# 7  2022-07-07 19:58:03.775139  1D Infinite Well           SSVQE_linear
# 8  2022-07-07 20:05:33.048136  1D Infinite Well           SSVQE_linear
# 9  2022-07-07 20:11:40.262585  1D Infinite Well           SSVQE_linear
# 10 2022-07-07 20:17:56.592081  1D Infinite Well           SSVQE_linear
# 11 2022-07-07 20:25:19.591695  1D Infinite Well           SSVQE_linear
# ...

# %%
sorted(a["Simulation Data"], key=lambda x:x[2])
a
# Out:
# Date/Time                                                    2022-07-07 19:58:03.775139
# Hamiltonian                                                            1D Infinite Well
# Weight Name                                                                SSVQE_linear
# n qubits                                                                              3
# Ansatz Name                                                   Hardware_Efficient_Ansatz
# Ansatz Id                                                                             0
# Ansatz Layers                                                                         1
# Optimizer                                                                          SPSA
# Optimizer Iterations                                                               1500
# Theoretical e0                                                                  2.95506
# Iters for e0 5-approx                                                              None
# ...

# %%
a
# Out:
# Date/Time                                                    2022-07-07 20:11:40.262585
# Hamiltonian                                                            1D Infinite Well
# Weight Name                                                                SSVQE_linear
# n qubits                                                                              3
# Ansatz Name                                                            Adiabatic_Ansatz
# Ansatz Id                                                                             2
# Ansatz Layers                                                                         1
# Optimizer                                                                          SPSA
# Optimizer Iterations                                                               1500
# Theoretical e0                                                                  2.95506
# Iters for e0 5-approx                                                                37
# ...
